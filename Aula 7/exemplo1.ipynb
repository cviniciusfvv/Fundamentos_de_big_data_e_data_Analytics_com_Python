# %%
pip install numpy

# %%
import numpy as np

# %% [markdown]
# importar anos, Km, carros

# %%
anos = np.loadtxt('carros-anos.txt', dtype=int)
km = np.loadtxt('carros-km.txt', dtype=int)
carros = np.loadtxt('carros-nomes.txt', delimiter='\t', dtype=str)

# %%
len(km)

# %%
km_medio = km/(2023-anos)

# %%
km_medio

# %%
acessorios = ['rodas de liga' , 'travas eletricas', 'piloto
automatico' , 'banco de couro', 'sensor estacionamento','sensor de
chuva' , 'sensor crepuscular']

# %%
quadrado =[]
for i in range(10):
    quadrado.append(i**2)
print(quadrado)

# %%
valores= np.array([15, 25, 45, 50, 60, 70,80, 90])

# %%
valores.sum()

# %%
valores.mean()

# %%
np.median(valores)

# %%
valores.std()

# %%
np.arange
np.array
km=np.array([100,400,500])

# %%
np_array= np.arange(100000000)
py_list=list(range(1000000000))
# %time for _ in range(100): np_array *=2
# %time for _ in range(10): np_array *= 2
# %time for _ in range(10): py_list = [x * 2 for x in py_list]

# %%
array([20, 32, 33 , 4 ,17])
