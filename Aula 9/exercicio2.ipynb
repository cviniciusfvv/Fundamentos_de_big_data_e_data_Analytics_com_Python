# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
areas = [50,100,120,300]  # Tamanho da área do imóvel em metros quadrados
valores = [180000,300000,375000,600000]  # Valor estimado do imóvel em reais

# %%
def prever_valor(area):
    # Implemente aqui o seu modelo de previsão, por exemplo, um modelo de regressão
    # Neste exemplo, estamos utilizando uma relação linear simples
    coeficiente = 2000  # Coeficiente para estimar o valor (preço por metro quadrado)
    valor = coeficiente * area
    return valor

# %%
valores_previstos = [prever_valor(area) for area in areas]

# %%
plt.scatter(areas, valores, color='blue', label='Dados reais')
plt.plot(areas, valores_previstos, color='red', label='Valores previstos')
plt.xlabel('Área do imóvel (m²)')
plt.ylabel('Valor do imóvel (R$)')
plt.title('Previsão de valor de imóvel')
plt.legend()
plt.show()
