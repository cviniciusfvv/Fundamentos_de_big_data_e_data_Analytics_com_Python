# %%
pip install panda
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv('monitoramento_tempo.csv',sep=',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\carlo\OneDrive\Área de Trabalho\Curso\Fundamentos_de_big_data_e_data_Analytics_com_Python\Aula 6\exercicio6.ipynb Célula 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/carlo/OneDrive/%C3%81rea%20de%20Trabalho/Curso/Fundamentos_de_big_data_e_data_Analytics_com_Python/Aula%206/exercicio6.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df=pd.read_csv('monitoramento_tempo.csv',sep=',')
#
# NameError: name 'pd' is not defined

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\carlo\OneDrive\Área de Trabalho\Curso\Fundamentos_de_big_data_e_data_Analytics_com_Python\Aula 6\exercicio6.ipynb Célula 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/carlo/OneDrive/%C3%81rea%20de%20Trabalho/Curso/Fundamentos_de_big_data_e_data_Analytics_com_Python/Aula%206/exercicio6.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df.info()
#
# NameError: name 'df' is not defined

# %%
plt.boxplot(df['pressão'])
plt.xlabel('data')
plt.ylabel('pressão')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bbe0ca27299c> in <cell line: 1>()
# ----> 1 plt.boxplot(df['pressão'])
#       2 plt.xlabel('data')
#       3 plt.ylabel('pressão')
#
# NameError: name 'plt' is not defined
