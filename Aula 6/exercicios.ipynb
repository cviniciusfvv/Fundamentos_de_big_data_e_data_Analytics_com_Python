# %% [markdown]
# Exercicios:

# %%
pip install panda
# Out:
# Requirement already satisfied: panda in c:\users\carlo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.3.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\lib\site-packages (from panda) (65.5.0)
# Requirement already satisfied: requests in c:\users\carlo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from panda) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\carlo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->panda) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\carlo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->panda) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\carlo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->panda) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\carlo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->panda) (2023.5.7)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
df=pd.read_csv('monitoramento_tempo.csv',sep=',')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %% [markdown]
# 1) Realizar anotações no gráfico de umidade

# %%
df['data']=pd.to_datetime(df['data'])
fig = plt.figure(figsize=(15,5))
eixo = fig.add_axes([0,0,1,1])
#eixo.set_ylim(200,500)
eixo.plot(df['data'],df['humidade'],color= 'g')
eixo.grid(True)
eixo.set_title('humidade no momento',fontsize=25, pad =20)
eixo.set_ylabel('humidade', fontsize=20)
eixo.set_xlabel('Ano', fontsize=20)
eixo.legend(['humidade'],loc='best')
eixo.axhline(max(df['humidade']),color='k',linestyle= '--')
eixo.axhline(min(df['humidade']),color='k',linestyle= '--')
x1=df['data'][df['humidade'].idxmax()]
y1 = max(df['humidade'])
x2= x1=df['data'][df['humidade'].idxmax()]
y2= max(df['humidade']) -5
eixo.annotate('Máximo',xy=(x1,y1),fontsize=20,xytext=(x2,y2), arrowprops=dict(facecolor='k'))
x1=df['data'][df['humidade'].idxmin()]
y1 = min(df['humidade'])
x2= x1=df['data'][df['humidade'].idxmin()]
y2= min(df['humidade']) +5
eixo.annotate('Mínimo',xy=(x1,y1),fontsize=20,xytext=(x2,y2), arrowprops=dict(facecolor='k'))
# Out:
# Text(2012-10-11 16:00:00, 15.0, 'Mínimo')

# %% [markdown]
# 2) Realizar anotações no gráfico de direção do vento

# %%
df['data']=pd.to_datetime(df['data'])
fig = plt.figure(figsize=(15,5))
eixo = fig.add_axes([0,0,1,1])
#eixo.set_ylim(200,500)
eixo.plot(df['data'],df['direção do vento'],color= 'g')
eixo.grid(True)
eixo.set_title('direção do vento no momento',fontsize=25, pad =20)
eixo.set_ylabel('direção do vento', fontsize=20)
eixo.set_xlabel('Ano', fontsize=20)
eixo.legend(['direção do vento'],loc='best')
eixo.axhline(max(df['direção do vento']),color='k',linestyle= '--')
eixo.axhline(min(df['direção do vento']),color='k',linestyle= '--')
x1=df['data'][df['direção do vento'].idxmax()]
y1 = max(df['direção do vento'])
x2= x1=df['data'][df['direção do vento'].idxmax()]
y2= max(df['direção do vento']) -5
eixo.annotate('Máximo',xy=(x1,y1),fontsize=20,xytext=(x2,y2), arrowprops=dict(facecolor='k'))
x1=df['data'][df['direção do vento'].idxmin()]
y1 = min(df['direção do vento'])
x2= x1=df['data'][df['direção do vento'].idxmin()]
y2= min(df['direção do vento']) +5
eixo.annotate('Mínimo',xy=(x1,y1),fontsize=20,xytext=(x2,y2), arrowprops=dict(facecolor='k'))
# Out:
# Text(2012-10-01 12:00:00, 5.0, 'Mínimo')

# %% [markdown]
# 3) Realizar anotações no gráfico de pressão

# %%
df['data']=pd.to_datetime(df['data'])
fig = plt.figure(figsize=(15,5))
eixo = fig.add_axes([0,0,1,1])
#eixo.set_ylim(200,500)
eixo.plot(df['data'],df['pressão'],color= 'g')
eixo.grid(True)
eixo.set_title('pressão no momento',fontsize=25, pad =20)
eixo.set_ylabel('pressão', fontsize=20)
eixo.set_xlabel('Ano', fontsize=20)
eixo.legend(['pressão'],loc='best')
eixo.axhline(max(df['pressão']),color='k',linestyle= '--')
eixo.axhline(min(df['pressão']),color='k',linestyle= '--')
x1=df['data'][df['pressão'].idxmax()]
y1 = max(df['pressão'])
x2= x1=df['data'][df['pressão'].idxmax()]
y2= max(df['pressão']) -5
eixo.annotate('Máximo',xy=(x1,y1),fontsize=20,xytext=(x2,y2), arrowprops=dict(facecolor='k'))
x1=df['data'][df['pressão'].idxmin()]
y1 = min(df['pressão'])
x2= x1=df['data'][df['pressão'].idxmin()]
y2= min(df['pressão']) +5
eixo.annotate('Mínimo',xy=(x1,y1),fontsize=20,xytext=(x2,y2), arrowprops=dict(facecolor='k'))
# Out:
# Text(2016-10-15 23:00:00, 973.0, 'Mínimo')

# %% [markdown]
# 4.Plotar boxplot para a umidade

# %%
plt.boxplot(df['humidade'])
plt.xlabel('data')
plt.ylabel('humidade')
# Out:
# Text(0, 0.5, 'humidade')

# %% [markdown]
# 5) Plotar boxplot para a direção do vento

# %%
plt.boxplot(df['direção do vento'])
plt.xlabel('data')
plt.ylabel('direção do vento')
# Out:
# Text(0, 0.5, 'direção do vento')

# %% [markdown]
# 6.Plotar boxplot para a pressão

# %%
plt.boxplot(df['pressão'])
plt.xlabel('data')
plt.ylabel('pressão')
# Out:
# Text(0, 0.5, 'pressão')
