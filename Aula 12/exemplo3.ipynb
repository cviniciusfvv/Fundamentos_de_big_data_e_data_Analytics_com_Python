# %%
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Passo 2: Carregar os dados dos filmes (exemplo hipotético)
dados_filmes = pd.DataFrame({
    'Gênero': ['Ação', 'Aventura', 'Comédia', 'Drama', 'Romance',
    'Terror', 'Suspense'],
    'Duração': [120, 150, 90, 120, 110, 100, 130],
    'Avaliação': [4.5, 4.2, 3.9, 4.1, 3.8, 4.3, 3.7]
})

# %%
# Passo 3: Visualizar os dados
print(dados_filmes)
# Passo 4: Pré-processamento dos dados (opcional)
# Neste exemplo hipotético, não há pré-processamento necessário.
# Passo 5: Aplicar o algoritmo DBSCAN
dbscan = DBSCAN(eps=10, min_samples=10) # Definindo os parâmetros eps e min_samples
clusters = dbscan.fit_predict(dados_filmes[['Duração', 'Avaliação']])
# Out:
#      Gênero  Duração  Avaliação
# 0      Ação      120        4.5
# 1  Aventura      150        4.2
# 2   Comédia       90        3.9
# 3     Drama      120        4.1
# 4   Romance      110        3.8
# 5    Terror      100        4.3
# 6  Suspense      130        3.7

# %%
# Passo 6: Avaliar o desempenho do modelo DBSCAN
numero_clusters = len(np.unique(clusters)) - 1 # Desconsiderando o cluster de ruído (-1)
print("Número de clusters:", numero_clusters)
# Passo 7: Visualizar os resultados do agrupamento
plt.scatter(dados_filmes['Duração'], dados_filmes['Avaliação'],
c=clusters)
plt.xlabel('Duração')
plt.ylabel('Avaliação')
plt.title('Agrupamento de Filmes')
plt.show()
# Passo 8: Analisar os grupos resultantes
dados_filmes['Cluster'] = clusters
grouped_data = dados_filmes.groupby('Cluster')
print(grouped_data)
# Out:
# Número de clusters: 0
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7fe92d5e9c00>

# %%
# Criando o gráfico em 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=labels)
ax.scatter(dados_filmes['Duração'], dados_filmes['Avaliação'], c=clusters)
ax.set_title('DBSCAN: %d clusters encontrados' % n_clusters)
ax.set_xlabel('Duração')
ax.set_ylabel('Nota')
ax.set_zlabel('Ruido')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\carlo\OneDrive\Área de Trabalho\Curso\Fundamentos_de_big_data_e_data_Analytics_com_Python\Aula 12\exemplo3.ipynb Célula 5 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/carlo/OneDrive/%C3%81rea%20de%20Trabalho/Curso/Fundamentos_de_big_data_e_data_Analytics_com_Python/Aula%2012/exemplo3.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> #ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=labels)
#       <a href='vscode-notebook-cell:/c%3A/Users/carlo/OneDrive/%C3%81rea%20de%20Trabalho/Curso/Fundamentos_de_big_data_e_data_Analytics_com_Python/Aula%2012/exemplo3.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> ax.scatter(dados_filmes['Duração'], dados_filmes['Avaliação'], c=clusters)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/carlo/OneDrive/%C3%81rea%20de%20Trabalho/Curso/Fundamentos_de_big_data_e_data_Analytics_com_Python/Aula%2012/exemplo3.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> ax.set_title('DBSCAN: %d clusters encontrados' % n_clusters)
#       <a href='vscode-notebook-cell:/c%3A/Users/carlo/OneDrive/%C3%81rea%20de%20Trabalho/Curso/Fundamentos_de_big_data_e_data_Analytics_com_Python/Aula%2012/exemplo3.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> ax.set_xlabel('Duração')
#       <a href='vscode-notebook-cell:/c%3A/Users/carlo/OneDrive/%C3%81rea%20de%20Trabalho/Curso/Fundamentos_de_big_data_e_data_Analytics_com_Python/Aula%2012/exemplo3.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> ax.set_ylabel('Nota')
#
# NameError: name 'n_clusters' is not defined

# %%
# Criando o gráfico em 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=labels)
ax.scatter(dados_filmes['Duração'], dados_filmes['Avaliação'], c=clusters)
ax.set_title('DBSCAN: %d clusters encontrados' % n_clusters)
ax.set_xlabel('Duração')
ax.set_ylabel('Nota')
ax.set_zlabel('Ruido')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       4 #ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=labels)
#       5 ax.scatter(dados_filmes['Duração'], dados_filmes['Avaliação'], c=clusters)
# ----> 6 ax.set_title('DBSCAN: %d clusters encontrados' % n_clusters)
#       7 ax.set_xlabel('Duração')
#       8 ax.set_ylabel('Nota')
#
# NameError: name 'n_clusters' is not defined
