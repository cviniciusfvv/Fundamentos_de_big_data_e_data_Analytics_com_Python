# %% [markdown]
# 3) Você é um cientista de dados em um laboratório médico e
# recebeu um conjunto de dados contendo os resultados de exames
# de sangue de hemograma de diferentes pacientes. Seu objetivo é
# utilizar o algoritmo Isolation Forest para identificar grupos de
# pacientes com anomalias
# Leucócitos = 2000,4000,5000,6500,
# Plaquetas = 100000,20000,80000,145000,
# Linfócitos = 2.3,4.5,6,5

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.ensemble import IsolationForest

# %%
leucocitos = np.array([2000, 4000, 5000, 6500])
plaquetas = np.array([100000, 20000, 80000, 145000])
linfocitos = np.array([2.3, 4.5, 6, 5])
dados = np.column_stack((leucocitos, plaquetas, linfocitos))

# %%
modelo = IsolationForest(contamination='auto', random_state=42)
modelo.fit(dados)
# Out:
# IsolationForest(random_state=42)

# %%
predicoes = modelo.predict(dados)
anomalias = dados[predicoes == -1]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plotar os pontos dos pacientes
ax.scatter(leucocitos, plaquetas, linfocitos, c='b', label='Pacientes')

# Plotar as anomalias em vermelho
ax.scatter(anomalias[:, 0], anomalias[:, 1], anomalias[:, 2], c='r', label='Anomalias')

# Configurar os rótulos dos eixos
ax.set_xlabel('Leucócitos')
ax.set_ylabel('Plaquetas')
ax.set_zlabel('Linfócitos')

# Adicionar uma legenda
ax.legend()

# Exibir o gráfico 3D
plt.show()
